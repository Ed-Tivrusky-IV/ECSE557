# %% [markdown]
# # SET-UP
#
#
# *   use pip to install aif360[all] library
# *   import some libraries. Specifically, import ClassificationMetric from aif360, which will compute fairness metrics later

# %% [markdown]
# # Reading Data
# read csv table from google drive and use StandardDataset function to create a StandardDataset object which has many convenient methods like split. Most importantly, you can use metrics function like ClassificationMetric only when you have converted dataframe to StandardDataset.
# What's more, StandardDataset will help us define privileged and unprivileged groups.

# %% [markdown]
# # Computing Fairness Metrics
#
# *   use logictic regression method to predict as before(in A1/A2)
# *   After training and testing, we use ClassificationMetric to compute three metrics: *statistical parity difference*, *equal opportunity difference*, *absolute average difference of equalized odds*

# %% [markdown]
# # Reweighing
#
#
# *   import reweighing function from aif360
# *   use this function to transfrom original training dataset and examine if we have eliminate statistical parity of training dataset after applying this method
# *   do the same things as above
