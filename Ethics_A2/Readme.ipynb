# %% [markdown]
# *I'm using diffprivlib-0.6.5*

# %% [markdown]
# # Creating classifier using logistic regression
#
#
# *   Read the csv file from google drive and list first 5 rows
# *   Split the Datasets into training and testing sets
# *   Since logistic regression algorithm requires numerical value, we need to use an encoder to transform non-numerical values
# *   Fit the model with data and predict the response values.
#
# After calculation, the accuracy for this classifier is 0.84

# %% [markdown]
# # Creating a differentially private logistic regression classifier
#
#
#
# *   Install the IBM differential privacy package and use the logistic regression model inside of it.
# *   Fit the model with data and predict the response values.
#
# After calculation, the accuracy for this classifier is 0.40

# %% [markdown]
# #Compare the differential private classifier's accuracy with the non-private classifier
#
# The accuracy has decreased dramatically from 0.84 to 0.40 with differential privacy protection when epsilon equals to 1. It's inevitable to find poorer accuracy when we want to protect our data.

# %% [markdown]
# # Calculate and illustrate how classification accuracy shifts with respect to different values of epsilon
#
#
#
# *   Select epsilon from 10^-2 to 10^2
# *   Use a x axis semi log graph to show the curve of accuracy with respect to epsilons
# ![accuracy-epsilon.png](data:image/png;base64,...)
# With observation of the graph, we can tell that the curve is a wavy function, with accuracy ranging from 0.36(epsilon=15)-0.68(epsilon=8).
# Epsilon is a metric of privacy loss at a differential change in data.

# %% [markdown]
# # Discuss what value of epsilon might be appropriate for this scenario. What is the accuracy trade-off with the chosen value of epsilon?
#
# I would choose epsilon=8 for where we can find the local highest accuracy. At the same time, a larger value for epsilon ensures the larger deviation from original datasets. However, more noise means lower accuracy, which is the trade-off we must consider.
